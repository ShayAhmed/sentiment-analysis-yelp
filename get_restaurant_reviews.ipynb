# %%
ls
# Out:
# README.MD
# data/
# get_restaurant_reviews.ipynb
# get_reviews.py
# load_save_restaurant_business_data.ipynb
# load_save_review_data.ipynb
# notebook_env.db
# req.txt
# separate_by_buisiness_id.ipynb
# test_models.ipynb

# %%
cd data
# Out:
# /Users/isabelli/Developer/DataSciLabFinalProject/sentiment-analysis-yelp/data

# %%
ls
# Out:
# business/                     reviews.csv
# business_data.csv             t.txt
# restaurant_business_data.csv

# %%
import pandas as pd
df_restaurants = pd.read_csv('restaurant_business_data.csv')
df_reviews = pd.read_csv('reviews.csv')

# %%
df_restaurants.head()
# Out:
#               business_id                 name state  stars  review_count  \
# 0  pQeaRpvuhoEqudo3uymHIQ  The Empanadas House    IL    4.5             5
# 1  CsLQLiRoafpJPJSkNX2h5Q     Middle East Deli    NC    3.0             5
# 2  eBEfgOPG7pvFhb2wcG9I7w      Philthy Phillys    ON    4.5             4
# 3  lu7vtrp_bE9PnxWfA8g4Pg         Banzai Sushi    ON    4.5             7
# 4  9sRGfSVEfLhN_km60YruTA   Apadana Restaurant    ON    3.0             3
#
#                                           categories  is_open
# 0  Ethnic Food, Food Trucks, Specialty Food, Impo...        1
# 1         Food, Restaurants, Grocery, Middle Eastern        0
# 2             Restaurants, Cheesesteaks, Poutineries        1
# 3       Japanese, Fast Food, Food Court, Restaurants        1
# 4  Persian/Iranian, Turkish, Middle Eastern, Rest...        1

# %%
df_restaurants.tail()
# Out:
#                   business_id               name state  stars  review_count  \
# 63939  xVpE01l6ZXdEtVf5PkRpDg              Julep    WI    4.0            95
# 63940  BAVuLTDmpSzDCk37A5HjtQ  Bruegger's Bagels    OH    3.0            13
# 63941  hskVqZCPqy-omm9CHi44xQ           Domino's    NC    2.0            16
# 63942  9Q0fPWAjUweoFDk0kafuzQ        Nishi Sushi    ON    4.0             5
# 63943  SYa2j1boLF8DcGVOYfHPcA          Five Guys    AZ    3.5            97
#
#                                               categories  is_open
# 63939     Nightlife, Diners, Bars, Southern, Restaurants        0
# 63940  Restaurants, Sandwiches, Food, Breakfast & Bru...        0
# 63941  Restaurants, Pizza, Sandwiches, Fast Food, Chi...        1
# 63942                  Japanese, Sushi Bars, Restaurants        0
# 63943  American (New), Food, Burgers, Restaurants, Fa...        1

# %%
df_reviews.head()
# Out:
#               business_id stars  useful  funny  cool  \
# 0  -MhfebM0QIsKt87iDN-FNw     2     5.0    0.0   0.0
# 1  lbrU8StCq3yDfr-QMnGrmQ     1     1.0    1.0   0.0
# 2  HQl28KMwrEKHqhFrrDqVNQ     5     1.0    0.0   0.0
# 3  5JxlZaqCnk1MnbgRirs40Q     1     0.0    0.0   0.0
# 4  IS4cv902ykd8wj1TR0N3-A     4     0.0    0.0   0.0
#
#                                                 text                 date
# 0  As someone who has worked with many museums, I...  2015-04-15 05:21:16
# 1  I am actually horrified this place is still in...  2013-12-07 03:16:52
# 2  I love Deagan's. I do. I really do. The atmosp...  2015-12-05 03:18:11
# 3  Dismal, lukewarm, defrosted-tasting "TexMex" g...  2011-05-27 05:30:52
# 4  Oh happy day, finally have a Canes near my cas...  2017-01-14 21:56:57

# %%
df_restaurants.shape
# Out:
# (63944, 7)

# %%
df_reviews.shape
# Out:
# (8021124, 7)

# %% [markdown]
# We should iterate over the reviews and check to see if the business ID is in the restaurants dataframe (rather than the other way around) to maximize efficiency. This way, we only have to process each review once- instead of searching over all reviews for each business.

# %%
restaurant_ids = df_restaurants.business_id.unique()

# %%
restaurant_ids.shape
# Out:
# (63944,)

# %%
restaurant_ids.dtype
# Out:
# dtype('O')

# %%
restaurant_set = set(restaurant_ids)

# %% [markdown]
# We convert the list of business IDs to a set for O(1) search time in the average case, optimizing from O(N) search time in the average case for lists

# %%
print(restaurant_set)
# Out:
# {'jJ2ca6wqp_YwTsdAWzplkQ', 'Y-Q1nngCx08_qCiqZWxzig', 'v9LrNSG9peTLoYY0x0FU8A', '_rxm3RZlb0reZDzCkKltow', 'i7LHTQ8gfLYDK-wF1ohtXg', 'RoyywlTNAmM8dJcibAr1rg', '-lrxtiCaTdCJ9h7uMndsUQ', 'UPjIiLldv0TD6y87fDofzg', '3_n3JdLWkyPCDtPSU-UyUQ', 'pqsNkM5pgbio1x-2HQoefw', 'ymbe8nqpYVCIpfgVl5MjYQ', 'VCrDdC_9PifJ0DU7Gk2MBQ', 'uzi4mgPIvvzALCgAFn1pNA', 'DA-ddRqcReCe_DcXKicvsQ', 'TETUKvUj73hzn6JpkJ4_QQ', '-8ILwSisSrTzcyy_Z0o9oA', 'OKG9gqnFBO2cRxkKhJ8ShA', 'WObxLCNQqSAV0_wUL0zJKA', 'cpWzrxF_7LfnZskje4PnaQ', '75lNzRwmjHpuMwSaNxrMBw', 'T7MemoFgPy6iNk4456vKWw', 'MHjhR_znpBr9S437VOmXKQ', 'xvTE4OJP5Yr_o-h3MTViuw', 'pIIvzkqj-b6ZS-vejo94fg', 'n5jTCFF6LqNIAz6Jx5-3tw', 'vsdc5yC1kJ29CCjCMjD4Vg', 'vxaFYMI3xdrdsFCaJI-Zcg', 'Qn58F_AcJJmLhsqJHtrIIg', 'ZaTbKhLraYurkcT7LrkSOA', 'kAE38-BVNGQxbuuyMnNbug', 'KSUpHqi0pu-rpouVs-KVdA', 'tq_hA-LBU_NJLmXq-yVw9A', 'QH7j0nPnGTBMmzEdM8PtBg', '0yZkGtnjZYxdW39aaKKzQg', 'kPwj57sDfiJxNkYw-4M9VQ', 'WleVOQ9YhBYl4SWrlsLDhA', '1PNOHJq2HNH98dPPxpUHkg', 'nCOctON_izR1j9fynkp3Zw', 'YLqO9xm5s0KJ9JzWukAk8Q', 'floQOUY3C_Tp80sAmu2DzA', 'x
# 3  5JxlZaqCnk1MnbgRirs40Q     1     0.0    0.0   0.0
# 4  IS4cv902ykd8wj1TR0N3-A     4     0.0    0.0   0.0
# 5  nlxHRv1zXGT0c0K51q3jDg     5     2.0    0.0   0.0
# 6  Pthe4qk5xh4n-ef-9bvMSg     5     1.0    0.0   0.0
#
#                                                 text                 date
# 2  I love Deagan's. I do. I really do. The atmosp...  2015-12-05 03:18:11
# 3  Dismal, lukewarm, defrosted-tasting "TexMex" g...  2011-05-27 05:30:52
# 4  Oh happy day, finally have a Canes near my cas...  2017-01-14 21:56:57
# 5  This is definitely my favorite fast food sub s...  2013-05-07 07:25:25
# 6  Really good place with simple decor, amazing f...  2015-11-05 23:11:05

# %%
df_res_reviews.shape
# Out:
# (5055992, 7)

# %%
df_res_reviews.to_csv('data/restaurant_reviews.csv', encoding='utf-8', index=False)

# %% [markdown]
# Stuff below was used for testing, doesn't need to be run

# %%
tx_business_ids = df_business[df_restaurants['state']=='TX']['business_id']

# %%
tx_business_ids.shape
# Out:
# (4,)

# %%
print(tx_business_ids)
# Out:
# 1579     wr6z01f4jcGQkRQMSw7nLg
# 24107    2SmVDHidtlfAF9bXBn4XwQ
# 31949    7j5yndEexyQn9cpVXLIIpw
# 34847    2H9lfg6In0Z5bFi0hbWOIg
# Name: business_id, dtype: object

# %%
on_business_ids = df_restaurants[df_restaurants['state']=='ON']['business_id']

# %%
on_business_ids.shape
# Out:
# (16221,)

# %%
df_business.head()
# Out:
#               business_id                 name state  stars  review_count  \
# 0  pQeaRpvuhoEqudo3uymHIQ  The Empanadas House    IL    4.5             5
# 1  CsLQLiRoafpJPJSkNX2h5Q     Middle East Deli    NC    3.0             5
# 2  eBEfgOPG7pvFhb2wcG9I7w      Philthy Phillys    ON    4.5             4
# 3  lu7vtrp_bE9PnxWfA8g4Pg         Banzai Sushi    ON    4.5             7
# 4  9sRGfSVEfLhN_km60YruTA   Apadana Restaurant    ON    3.0             3
#
#                                           categories  is_open
# 0  Ethnic Food, Food Trucks, Specialty Food, Impo...        1
# 1         Food, Restaurants, Grocery, Middle Eastern        0
# 2             Restaurants, Cheesesteaks, Poutineries        1
# 3       Japanese, Fast Food, Food Court, Restaurants        1
# 4  Persian/Iranian, Turkish, Middle Eastern, Rest...        1

# %%
nc_business_ids = df_business[df_business['state']=='NC']['business_id']

# %%
nc_business_ids.shape
# Out:
# (4655,)

# %%
ca_business_ids = df_business[df_business['state']=='CA']['business_id']

# %%
ca_business_ids.shape
# Out:
# (3,)

# %%
az_restaurant_ids = df_restaurants[df_restaurants['state']=='AZ']['business_id']

# %%
az_restaurant_ids.shape
# Out:
# (12124,)

# %%
pa_restaurant_ids = df_restaurants[df_restaurants['state']=='PA']['business_id']

# %%
pa_restaurant_ids.shape
# Out:
# (4259,)
