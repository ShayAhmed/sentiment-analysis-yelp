# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Shehryar/Downloads/Alldone_1hot_v1.csv")

# %%
data.head()
# Out:
#    Unnamed: 0   latitude  longitude  stars  review_count  is_open  fbcheckins  \
# 0           0  43.633291 -79.531768    3.0            13        0         NaN
# 1           1  43.666376 -79.348773    4.0           116        1      1252.0
# 2           2  43.649859 -79.382060    3.0             8        1        43.0
# 3           3  43.765279 -79.326248    3.0            11        1         NaN
# 4           4  43.685608 -79.313936    4.5            24        1         NaN
#
#    rating_count  engagement.count  pos_reviews  ...  SunHoursClose_2145  \
# 0           NaN               NaN           11  ...                   0
# 1          15.0              88.0          109  ...                   0
# 2           0.0               0.0            7  ...                   0
# 3           NaN               NaN            8  ...                   0
# 4           NaN               NaN           24  ...                   0
#
# ...

# %%
cols = data.columns
data['attributes.RestaurantsAttire_\'casual\'']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 8674    0
# 8675    0
# 8676    0
# 8677    1
# 8678    0
# Name: attributes.RestaurantsAttire_'casual', Length: 8679, dtype: int64
